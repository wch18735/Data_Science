# %% [markdown]
# # Linear Regression (선형회귀)
# ### Ex1: Linear regression with two variables (y = wx + b)

# %%
# ex1: linear regression with two variables (y = wx + b)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

n = 100
x = np.random.randn(n)                # batch size
y = x*20 + 10                         # w=20, b=10
y = y + np.random.randn(n) * 10       # add noise

# x,y
#### just to see the data
plt.figure(figsize=(4,4)) # plotting a circle
plt.scatter(x,y)
##################\

w=np.random.randn()   # randn = normal distribution: meqn=0, signma=1, rand= (0,1)
b=np.random.randn()

lr = 0.2                                 # learning rate
n_epoch = 200

for epoch in range(n_epoch):
    y_pred = w*x + b
    error = ((y_pred - y)**2).mean()     # mean square error

    w = w - lr* ((y_pred - y)*x).mean()
    b = b - lr* (y_pred - y).mean()
    if epoch %10 == 0:
        print('epoch=', epoch, 'error=', error, 'w=', w, 'b=', b)
        
print('---------------------------')
print('epoch=', epoch, 'error=', error, 'w=', w, 'b=', b)

xx = np.linspace(-5,5,100) 
yy = w * xx + b
plt.plot(xx,yy,c='k')
# Out:
# epoch= 0 error= 792.939794773477 w= 4.410869472071317 b= -0.5430241630894073
# epoch= 10 error= 99.67036582380376 w= 20.163499671571184 b= 9.031891332494418
# epoch= 20 error= 93.4763743112719 w= 21.5749289999811 b= 10.061637780121503
# epoch= 30 error= 93.41938309410405 w= 21.70141046884962 b= 10.172353607306588
# epoch= 40 error= 93.41884163347409 w= 21.712746695831797 b= 10.18425486042429
# epoch= 50 error= 93.41883631759104 w= 21.713762941177617 b= 10.185533933773538
# epoch= 60 error= 93.41883626373219 w= 21.71385406551034 b= 10.185671379561821
# epoch= 70 error= 93.41883626317083 w= 21.71386223879457 b= 10.185686147226777
# epoch= 80 error= 93.41883626316479 w= 21.71386297214229 b= 10.185687733748155
# epoch= 90 error= 93.41883626316474 w= 21.713863037969244 b= 10.185687904176358
# epoch= 100 error= 93.41883626316472 w= 21.71386304388095 b= 10.185687922482838
# epoch= 110 error= 93.41883626316476 w= 21.71386304441217 b= 10.185687924449102
# epoch= 120 error= 93.41883626316476 w= 21.71386304445994 b= 10.185687924660284
# epoch= 130 error= 93.41883626316476 w= 21.71386304446424 b= 10.185687924682965
# epoch= 140 error= 93.41883626316474 w= 21.71386304446463 b= 10.1856879246854
# epoch= 150 error= 93.41883626316474 w= 21.71386304446466 b= 10.185687924685661
# epoch= 160 error= 93.41883626316474 w= 21.71386304446466 b= 10.18568792468569
# epoch= 170 error= 93.41883626316474 w= 21.71386304446466 b= 10.18568792468569
# epoch= 180 error= 93.41883626316474 w= 21.71386304446466 b= 10.18568792468569
# epoch= 190 error= 93.41883626316474 w= 21.71386304446466 b= 10.18568792468569
# ---------------------------
# epoch= 199 error= 93.41883626316474 w= 21.71386304446466 b= 10.18568792468569

# %% [markdown]
# ### Ex2: Training two features (x1, x2)  ( y = w1*x1 + w2*x2 + b)

# %%
# ex 2 : training two parameters w1, w2 and b (y = w1*x1 + w2*x2 + b)

import numpy as np
import pandas as pd

n=100
x1 = np.random.randn(n)             # randn=normal distribution in (-1,1), rand=(0,1)
x2 = np.random.randn(n)

y = x1*30 + x2*40 + 50
y = y + np.random.randn(n)*20      # add noise

w1 = np.random.rand()               # initial guess
w2 = np.random.rand()
b = np.random.rand()

lr = 0.2                            # learning rate
n_epoch = 200                      # no of epoch
for epoch in range(n_epoch):
    y_pred = w1*x1 + w2*x2 + b
    error = ((y_pred - y)**2).mean()

    w1 = w1 - lr* ((y_pred - y)*x1).mean()
    w2 = w2 - lr* ((y_pred - y)*x2).mean()
    b = b - lr* (y_pred - y).mean()
    if epoch %10 == 0:
        print('epoch=', epoch, 'error=', error, 'w1=', w1, 'w2=', w2, 'b=', b)
        
print('---------------------------')
print('epoch=', epoch, 'error=', error, 'w1=', w1, 'w2=', w2, 'b=', b)
# Out:
# epoch= 0 error= 3927.956803993499 w1= 4.569154999796158 w2= 5.441052223396434 b= 8.90004373050167
# epoch= 10 error= 493.06480796590967 w1= 23.016085709985905 w2= 30.53805293480463 b= 43.01816444019993
# epoch= 20 error= 369.73175934138175 w1= 26.408391787881637 w2= 37.04174824298266 b= 48.187844715168815
# epoch= 30 error= 364.40532336345115 w1= 27.0368830991929 w2= 38.57175021995722 b= 49.08294650628726
# epoch= 40 error= 364.16115461106574 w1= 27.156955939875665 w2= 38.917353334486876 b= 49.25357473971547
# epoch= 50 error= 364.1497581377527 w1= 27.18071114846085 w2= 38.99393000807728 b= 49.28807426816447
# epoch= 60 error= 364.14922325126236 w1= 27.18555415437335 w2= 39.0107327302866 b= 49.295282499218125
# epoch= 70 error= 364.1491981024573 w1= 27.186563794015726 w2= 39.01440073641743 b= 49.29681518295911
# epoch= 80 error= 364.1491969193591 w1= 27.18677749431543 w2= 39.015199230183114 b= 49.297144104142404
# epoch= 90 error= 364.149196863691 w1= 27.186823168316465 w2= 39.015372788800626 b= 49.29721503912964
# epoch= 100 error= 364.14919686107146 w1= 27.186832989067522 w2= 39.01541048071388 b= 49.29723037722748
# epoch= 110 error= 364.14919686094834 w1= 27.186835108389577 w2= 39.01541866234658 b= 49.29723369849323
# epoch= 120 error= 364.14919686094237 w1= 27.186835566728384 w2= 39.01542043781278 b= 49.29723441823677
# epoch= 130 error= 364.1491968609422 w1= 27.18683566597787 w2= 39.01542082303978 b= 49.29723457427907
# epoch= 140 error= 364.1491968609421 w1= 27.186835687485512 w2= 39.01542090661588 b= 49.29723460811778
# epoch= 150 error= 364.1491968609421 w1= 27.186835692148296 w2= 39.015420924747005 b= 49.29723461545693
# epoch= 160 error= 364.14919686094225 w1= 27.186835693159427 w2= 39.015420928680285 b= 49.297234617048815
# epoch= 170 error= 364.1491968609422 w1= 27.186835693378725 w2= 39.01542092953354 b= 49.29723461739412
# epoch= 180 error= 364.14919686094225 w1= 27.18683569342629 w2= 39.01542092971864 b= 49.29723461746902
# epoch= 190 error= 364.1491968609422 w1= 27.18683569343661 w2= 39.01542092975879 b= 49.29723461748527
# ---------------------------
# epoch= 199 error= 364.1491968609422 w1= 27.186835693438745 w2= 39.015420929767096 b= 49.297234617488634

# %% [markdown]
# ### Ex3: Using regression function (LinearRegression)

# %%
# ex3: using regression function (LinearRegression)

from sklearn.linear_model import LinearRegression
x1 = np.random.randn(n)
x2 = np.random.randn(n)

y = x1*30 + x2*40 + 50
y = y + np.random.randn(n)*20      # add noise

X = pd.DataFrame(x1)

X[1] =x2

model = LinearRegression()        # create model
model.fit(X,y)                    # train model
print('w1=', model.coef_[0], 'w2=', model.coef_[1], 'b=', model.intercept_)

# print (model.coef_)              # see the result
# print (model.intercept_)

new_X=[1,3]
print(model.predict([new_X]))      # prediction

z=np.random.rand(10,2)

# print (z)
print(model.predict(z))
# Out:
# w1= 30.43851910774899 w2= 42.66201139386768 b= 49.94563094880428
# [208.37018424]
# [ 97.54937063  92.10276128 100.2665582   94.28464836  79.65291215
#   92.213833    63.18297341 108.58524104 115.47107364  97.84317988]

# %% [markdown]
# # Classification (선형분류)
# ### Ex1: Linear classification with two variables
# - data generated by myself
# - uses MSE as loss function (error = (sigmoid(x) - y)**2)

# %%
### for classification
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
N = 200
x1_p = np.random.randn(int(N/2))
x2_p = -1.7 * x1_p + 0.8 + np.random.rand(n) * 1.7
x1_n = np.random.randn(int(N/2))
x2_n = -1.7 * x1_n + 0.8 - np.random.rand(n) * 2.4

# plt.scatter(x1_p, x2_p)
# plt.scatter(x1_n, x2_n)
# xx = np.linspace(-4, 4,100)
# plt.plot(xx, 0.7*xx + 1.3)
# plt.plot()
# plt.show()

X1 = np.concatenate((x1_p, x1_n))
X2 = np.concatenate((x2_p, x2_n))

X = np.concatenate((X1.reshape(-1,1), X2.reshape(-1,1)), axis=1)

bias_factor = np.ones(X.shape[0]).reshape(-1,1)
X = np.concatenate((X, bias_factor), axis=1)
X.shape

y1=np.ones(len(x1_p))
y0=np.zeros(len(x1_n))
y = np.hstack((y1,y0))

W = np.random.randn(X.shape[1])   # initial W value

def sigmoid_activation(x):
    return 1.0 / (1 + np.exp(-x))

lossHistory = []
epochs = 100
alpha = 0.1

for epoch in np.arange(epochs):
    preds = sigmoid_activation(X.dot(W))
    error = preds - y
    loss = (error**2).sum()    # mean squares error
    lossHistory.append(loss)
    #  print("[INFO] epoch #{}, loss={:.7f}".format(epoch + 1, loss))
    
    gradient = X.T.dot(error) / X.shape[0]
    W = W - alpha * gradient

w1, w2, b = W[0], W[1], W[2]
x1, x2 = X[:,0], X[:,1]
print(w1, w2, b)
accuracy = ((sigmoid_activation(w1*x1 + w2*x2 + b) > 0.5) == y).sum()/N
print(accuracy)

plt.scatter(X[:,0], X[:,1], c=y)
xx = np.linspace(-3,6,100)
yy = -w1/w2 * xx -b/w2
plt.plot(xx, yy)
# Out:
# 1.6490047770769203 1.3452944771333952 -0.7371942143369807
# 0.935

# %%
# construct a figure that plots the loss over time
fig = plt.figure()
plt.ylim([0.,90])
plt.plot(np.arange(0, epochs), lossHistory)
fig.suptitle("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ### Ex2: same as Ex1
# - Data generation using make_blobs()

# %%
from sklearn.datasets import make_blobs
N = 300
(X, y) = make_blobs(n_samples=N, n_features=2, centers=2, 
                    cluster_std=1.5, random_state=20)
plt.scatter(X[:,0], X[:,1], c=y)
bias_factor = np.ones(X.shape[0]).reshape(-1,1)
X = np.concatenate((X, bias_factor), axis=1)
print(X.shape, y.reshape(-1,1).shape)

# just to see in dataframe form
arr = np.concatenate((X, y.reshape(-1,1)), axis=1)
df = pd.DataFrame(arr)

# start gradient descent algorithm
W = np.random.randn(X.shape[1])   # initial W value

def sigmoid_activation(x):
    return 1.0 / (1 + np.exp(-x))

lossHistory = []
epochs = 1000
alpha = 0.01
plt.scatter(X[:,0], X[:,1], c=y)

for epoch in np.arange(epochs):
    preds = sigmoid_activation(X.dot(W))
    error = preds - y
    loss = (error**2).sum()    # mean squares error
    
    lossHistory.append(loss)
   
    gradient = X.T.dot(error)/X.shape[0]
    W = W - alpha * gradient

w1, w2, b = W[0], W[1], W[2]
x1, x2 = X[:,0], X[:,1]
print(w1, w2, b)
accuracy = ((sigmoid_activation(w1*x1 + w2*x2 + b) > 0.5) == y).sum()/N
print(accuracy)

plt.scatter(X[:,0], X[:,1], c=y)
xx = np.linspace(-2,10,100)
yy = -w1/w2 * xx -b/w2
plt.plot(xx, yy)
# Out:
# (300, 3) (300, 1)
# 1.3005483485495724 -0.8387079387285032 0.030905788421690287
# 0.9866666666666667

# %%
# construct a figure that plots the loss over time
fig = plt.figure()
plt.ylim([0.,100])
plt.plot(np.arange(0, epochs), lossHistory)
fig.suptitle("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ### Ex3: use library function
# - use SGDClassifier()

# %%
from sklearn.linear_model import SGDClassifier

clf = SGDClassifier()      
clf.fit(X[:,:2], y)    
print(clf.score(X[:, :2],y))

print(clf.coef_, clf.intercept_)

w1, w2, b = clf.coef_[0,0], clf.coef_[0,1], clf.intercept_
plt.scatter(X[:,0], X[:,1], c=y)
xx = np.linspace(-2,10,100)
yy = -w1/w2 * xx -b/w2
plt.plot(xx, yy, c='r')
# Out:
# 0.98
# [[135.01794374 -73.61246541]] [-55.41173894]

# %% [markdown]
# # Ex4: Using Cross Entropy as loss function (*******************)
# - Classification by Calculating parameters one by one
# - using CrossEntropy  as loss function
# - number of features = 2

# %%
from sklearn.datasets import make_blobs

np.random.seed(7)
N = 300
(X, y) = make_blobs(n_samples=N, n_features=2, centers=2, cluster_std=1.5, random_state=17)
x1, x2 = X[:,0], X[:,1]

w1 = np.random.randn()   # initial W value
w2 = np.random.randn()   # initial W value
b = np.random.randn()   # initial W value

def sigmoid_activation(x):
    return 1.0 / (1 + np.exp(-x))

lossHistory = []
epochs = 300
alpha = 0.01

for epoch in np.arange(epochs):
    preds = sigmoid_activation(w1*x1 + w2*x2 + b)       # prediction
    # error = preds - y
    loss = -((y*np.log(preds) + (1-y)*np.log(1-preds))).mean()  # loss = cross entropy
    lossHistory.append(loss)
    
    dloss_dz = preds - y
    w1_deriv = dloss_dz * x1        # d(loss)/dw1 = d(loss)/dz * dz/dw1
    w2_deriv = dloss_dz * x2
    b_deriv = dloss_dz * 1
    
    w1 = w1 - (alpha * w1_deriv).mean()
    w2 = w2 - (alpha * w2_deriv).mean()
    b  = b  - (alpha * b_deriv).mean()

print(w1, w2, b)
accuracy = ((sigmoid_activation(w1*x1 + w2*x2 + b) > 0.5) == y).sum()/N
print(accuracy)

# plt.ylim([-2,15])
plt.scatter(X[:,0], X[:,1], c=y)
xx = np.linspace(-10,5,100)
yy = -w1/w2 * xx -b/w2
plt.plot(xx, yy)
plt.show()

# construct a figure that plots the loss over time
fig = plt.figure()
plt.plot(np.arange(0, epochs), lossHistory)
plt.ylim([0.,1.])
fig.suptitle("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.show()
# Out:
# 0.9304389249940906 -1.3620824041560857 0.06538761750887857
# 0.9766666666666667

# %% [markdown]
# ### Ex5: Using Library Function
# - SGDClassifier()

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.datasets import make_blobs

N = 300
(X, y) = make_blobs(n_samples=N, n_features=2, centers=2, 
                    cluster_std=1.5, random_state=17)
clf = SGDClassifier()      
clf.fit(X[:,:2], y)    
print(clf.score(X[:, :2],y))

print(clf.coef_, clf.intercept_)

plt.scatter(X[:,0], X[:,1], c=y)
w1, w2, b = clf.coef_[0,0], clf.coef_[0,1], clf.intercept_
xx = np.linspace(-10,5,100)
yy = -w1/w2 * xx -b/w2
plt.plot(xx, yy, c='r')
plt.show()
# Out:
# 0.9966666666666667
# [[-12.99056518 -35.78107078]] [-192.59242548]

# %% [markdown]
# # 연습

# %%
predicted = sigmoid_activation(w1*x1 + w2*x2 + b) > 0.5
accuracy = (predicted == y).sum()/N
print(accuracy)
# Out:
# 0.9966666666666667

# %% [markdown]
# # Cross entropy 연습
# - ![image.png](attachment:image.png)
# - This is the most common setting for classification problems. Cross-entropy loss increases as the predicted probability diverges from the actual label.
# - Notice that when actual label is 1 (y(i) = 1), second half of function disappears whereas in case actual label is 0 (y(i) = 0) first half is dropped off.
# - In short, we are just multiplying the log of the actual predicted probability for the ground truth class. An important aspect of this is that cross entropy loss penalizes heavily the predictions that are confident but wrong.

# %%
import numpy as np

def cross_entropy(predictions, targets, epsilon=1e-12):
    """
    Computes cross entropy between targets (encoded as one-hot vectors)
    and predictions. 
    Input: predictions (N, k) ndarray
           targets (N, k) ndarray        
    Returns: scalar
    """
    predictions = np.clip(predictions, epsilon, 1. - epsilon)
    N = predictions.shape[0]
    ce = -np.sum(targets*np.log(predictions+1e-9))/N
    return ce

predictions = np.array([[0.25,0.25,0.25,0.25],    # multi-class?
                        [0.01,0.01,0.01,0.96]])
targets = np.array([[0,0,0,1],
                    [0,0,0,1]])
ans = 0.71355817782  #Correct answer
x = cross_entropy(predictions, targets)
print(np.isclose(x,ans))
# Out:
# True

# %%
cross_entropy_loss = cross_entropy(predictions, targets)
print ("Cross entropy loss is: " + str(cross_entropy_loss))
# Out:
# Cross entropy loss is: 0.7135329699138555

# %% [markdown]
# ### in machine learning training
# - ![image.png](attachment:image.png)

# %% [markdown]
# - 이를 Log-loss 라고도 함. 확률 p를 계산하기 위해 시그모이드 함수를 사용할 수 있습니다. 여기서 z는 input feature 의 함수이다.
# ![image.png](attachment:image.png)

# %% [markdown]
# - ![image.png](attachment:image.png)

# %% [markdown]
# - ![image.png](attachment:image.png)

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
# Data for three-dimensional scattered points

ax.scatter3D(x1, x2, y, c=y);

# xx = np.linspace(-2,3,100) 
# yy = np.linspace(-2,2,100)
zz = w1*x1 + w2*x2 + b
ax.plot(xx,yy, w1*xx + w2*yy + b, c='k')
